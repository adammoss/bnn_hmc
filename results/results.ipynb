# %% [markdown]
# <a href="https://colab.research.google.com/github/adammoss/bnn_hmc/blob/main/results/results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import shutil
import glob
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from google.colab import drive

# %%
# %env XLA_FLAGS=--xla_gpu_cuda_data_dir=/usr/local/cuda-11.2
# Out:
# env: XLA_FLAGS=--xla_gpu_cuda_data_dir=/usr/local/cuda-11.2

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Tue Nov 15 10:05:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   28C    P0    43W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install astro-datasets --upgrade
# !pip install tensorflow_datasets --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !pip install --upgrade https://storage.googleapis.com/jax-releases/cuda111/jaxlib-0.1.65+cuda111-cp37-none-manylinux2010_x86_64.whl
# !pip install jax==0.2.12
# !pip install dm-haiku==0.0.5.dev0 optax==0.0.6 chex==0.0.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://storage.googleapis.com/jax-releases/cuda111/jaxlib-0.1.65+cuda111-cp37-none-manylinux2010_x86_64.whl (189.4 MB)
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
shutil.rmtree('bnn_hmc', ignore_errors=True)

# %%
# !git clone https://github.com/adammoss/bnn_hmc
# Out:
# Cloning into 'bnn_hmc'...
# remote: Enumerating objects: 1291, done.
# remote: Counting objects: 100% (288/288), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 1291 (delta 193), reused 279 (delta 188), pack-reused 1003
# Receiving objects: 100% (1291/1291), 1.56 MiB | 10.48 MiB/s, done.
# Resolving deltas: 100% (873/873), done.

# %%
# !python3 bnn_hmc/data_scripts/run_de.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Size...:   1% 8/767 [00:04<03:16,  3.86 MiB/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Size...:   1% 10/767 [00:04<02:19,  5.41 MiB/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Size...:   2% 13/767 [00:04<01:46,  7.08 MiB/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Size...:   2% 15/767 [00:04<01:14, 10.07 MiB/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Size...:   2% 17/767 [00:04<01:05, 11.37 MiB/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# Dl Size...:   2% 19/767 [00:04<00:59, 12.50 MiB/s]
# Dl Completed...:   0% 0/1 [00:04<?, ? url/s]
# ...

# %%
# !python3 bnn_hmc/data_scripts/run_vi.py
# Out:
# Performing VI
# JAX sees the following devices: [GpuDevice(id=0, process_index=0)]
# TF sees the following devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Namespace(batch_size=53, builder_kwargs=None, dataset_name='mirabest/confident', dir='runs/vi/mirabest/confident/0/', ensemble_exclude_metric=None, ensemble_exclude_value=1.0, ensemble_root=None, eval_freq=5, eval_split=None, image_size=64, init_checkpoint=None, init_step_size=0.0001, mean_init_checkpoint=None, model_name='lenet', momentum_decay=0.9, num_epochs=300, optimizer='Adam', output_prefix=None, patience=20, save_freq=20, scaling=None, seed=0, subset_train_to=20000, tabulate_freq=40, temperature=1.0, test_builder_kwargs=None, test_dataset_name=None, test_split='train[80%:]', tpu_ip=None, train_split='train[:80%]', use_float64=False, vi_ensemble_size=20, vi_sigma_init=0.01, weight_decay=5)
# ...

# %%
# !cd bnn_hmc && git checkout dropout_wip
# Out:
# Branch 'dropout_wip' set up to track remote branch 'dropout_wip' from 'origin'.
# Switched to a new branch 'dropout_wip'

# %%
# !python3 bnn_hmc/data_scripts/run_mcd.py
# Out:
# Performing MCD
# JAX sees the following devices: [GpuDevice(id=0, process_index=0)]
# TF sees the following devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# tcmalloc: large alloc 1183137792 bytes == 0x11be4000 @  0x7f31e6f2e887 0x7f31d4ff37ce 0x7f31d4ff82c2 0x7f31d4ffe8a2 0x7f31d4ffee7d 0x7f31d4fff1e9 0x7f31d45f0f11 0x7f31d45ec19f 0x7f31d4b07d01 0x7f31d460b594 0x7f31d460c126 0x7f31d3d21a69 0x7f31d3d1b4e0 0x7f31d3d25a3c 0x7f31d3d15ba6 0x7f31d3ae2fa5 0x7f31d3ad8961 0x58f6e4 0x590691 0x510946 0x58fd37 0x50c4fc 0x5b4ee6 0x58ff2e 0x510325 0x4d01b4 0x4df4c4 0x5a04c4 0x5a2ed4 0x5909f6 0x510280
# Starting from random initialization with provided seed
# ...

# %%
# !zip -r bnn_results.zip /content/runs -x "*step*.pt"
# Out:
# updating: content/runs/ (stored 0%)
# updating: content/runs/mcd/ (stored 0%)
# updating: content/runs/mcd/mirabest/ (stored 0%)
# updating: content/runs/mcd/mirabest/confident/ (stored 0%)
# updating: content/runs/mcd/mirabest/confident/0/ (stored 0%)
# updating: content/runs/mcd/mirabest/confident/0/sgd__opt_sgd_0.9__lr_sch_i_3e-07___epochs_300_wd_10_batchsize_53_temp_1.0/ (stored 0%)
# updating: content/runs/mcd/mirabest/confident/0/sgd__opt_sgd_0.9__lr_sch_i_3e-07___epochs_300_wd_10_batchsize_53_temp_1.0/command.sh (stored 0%)
# updating: content/runs/mcd/mirabest/confident/0/sgd__opt_sgd_0.9__lr_sch_i_3e-07___epochs_300_wd_10_batchsize_53_temp_1.0/events.out.tfevents.1668506648.1eed0b629f7c.1106.0.v2 (deflated 11%)
# updating: content/runs/sgd/ (stored 0%)
# updating: content/runs/sgd/mirabest/ (stored 0%)
# updating: content/runs/sgd/mirabest/confident/ (stored 0%)
# updating: content/runs/sgd/mirabest/confident/0/ (stored 0%)
# ...

# %%
# !cp /content/bnn_results.zip /content/drive/MyDrive
